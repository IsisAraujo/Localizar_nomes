# %% [markdown]
# # Imports Libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import inflection
#Next line helps with rendering plots
# %matplotlib inline
import matplotlib as mpl #add'l plotting functionality
mpl.rcParams['figure.dpi'] = 400 #high res figures
#from imports
from numpy.random import default_rng

# %%
df=pd.read_excel("C:/Users/55799/Desktop/Repos/1cipm/chacara.xls")

# %%
df.shape
# Out:
# (14742, 28)

# %%
print('Number of rows: {}'.format(df.shape[0]))
print('Number of columns: {}'.format(df.shape[1]))
# Out:
# Number of rows: 14742
# Number of columns: 28

# %% [markdown]
# ### NA Check / Rename e Drop Columns
#
# Checking missing data

# %%
df.isna().sum()
# Out:
# Data de Criação              0
# Hora de Criação              0
# Ocorrência                   0
# Endereço                     0
# Bairro                     108
# Município                    3
# Cód. Tipo                    0
# Descrição                    0
# Cód. Sub Tipo               48
# Desc. Sub Tipo              48
# Sit. Encontrada          14742
# Batalhão                     0
# COMPANHIA                    0
# Viatura                   4845
# Cód. Final.                 22
# Descrição Finalização       22
# Obs. Finalização          9747
# Solicitante                 11
# Telefone                    68
# XCORD                        0
# YCORD                        0
# Aberto                       0
# Despachado                   0
# Tempo Despacho               0
# Chegada Local                0
# Tempo Deslocamento           0
# Fechado                      0
# Placa                    14742
# dtype: int64

# %%
df.columns
# Out:
# Index(['Data de Criação', 'Hora de Criação', 'Ocorrência', 'Endereço',
#        'Bairro', 'Município', 'Cód. Tipo', 'Descrição', 'Cód. Sub Tipo',
#        'Desc. Sub Tipo', 'Sit. Encontrada', 'Batalhão', 'COMPANHIA', 'Viatura',
#        'Cód. Final.', 'Descrição Finalização', 'Obs. Finalização',
#        'Solicitante', 'Telefone', 'XCORD', 'YCORD', 'Aberto', 'Despachado',
#        'Tempo Despacho', 'Chegada Local', 'Tempo Deslocamento', 'Fechado',
#        'Placa'],
#       dtype='object')

# %%
cols_old=['Data de Criação', 'Hora de Criação', 'Ocorrência', 'Endereço',
       'Bairro', 'Município', 'Cód. Tipo', 'Descrição', 'Cód. Sub Tipo',
       'Desc. Sub Tipo', 'Sit. Encontrada', 'Batalhão', 'COMPANHIA', 'Viatura',
       'Cód. Final.', 'Descrição Finalização', 'Obs. Finalização',
       'Solicitante', 'Telefone', 'XCORD', 'YCORD', 'Aberto', 'Despachado',
       'Tempo Despacho', 'Chegada Local', 'Tempo Deslocamento', 'Fechado',
       'Placa']

snakecase=lambda x: inflection.underscore(x)

cols_new=list(map(snakecase, cols_old))

#raname
df.columns=cols_new

# %%
df.sample().T
# Out:
#                                                                 7628
# data de criação                                           01/11/2020
# hora de criação                                             00:37:17
# ocorrência                                                  M2440437
# endereço                         POV CARDOSO, 2 :NUMERAL INFORMADO 0
# bairro                                                           .NI
# município                                             .SAO CRISTOVAO
# cód. tipo                                                     E08420
# descrição              PERTURBACAO DO TRABALHO OU DO SOSSEGO ALHEIOS
# cód. sub tipo                                               E08420.1
# desc. sub tipo                                         EM RESIDENCIA
# sit. encontrada                                                  NaN
# batalhão                                                       1CIPM
# companhia                                                      1CIPM
# ...

# %%
df1=df.copy()

# %%
df1.columns
# Out:
# Index(['data de criação', 'hora de criação', 'ocorrência', 'endereço',
#        'bairro', 'município', 'cód. tipo', 'descrição', 'cód. sub tipo',
#        'desc. sub tipo', 'sit. encontrada', 'batalhão', 'companhia', 'viatura',
#        'cód. final.', 'descrição finalização', 'obs. finalização',
#        'solicitante', 'telefone', 'xcord', 'ycord', 'aberto', 'despachado',
#        'tempo despacho', 'chegada local', 'tempo deslocamento', 'fechado',
#        'placa'],
#       dtype='object')

# %%
df1=df1.drop(['batalhão', 'companhia', 'viatura',
       'cód. final.',  'solicitante', 'telefone', 'xcord', 'ycord', 'aberto', 'despachado',
       'tempo despacho', 'chegada local', 'tempo deslocamento', 'fechado',
       'placa'], axis=1)

# %%
df1.columns
# Out:
# Index(['data de criação', 'hora de criação', 'ocorrência', 'endereço',
#        'bairro', 'município', 'cód. tipo', 'descrição', 'cód. sub tipo',
#        'desc. sub tipo', 'sit. encontrada', 'descrição finalização',
#        'obs. finalização'],
#       dtype='object')

# %%
df1=df1.rename(columns={'data de criação':'data',
                        'hora de criação': 'hora', 
                        'cód. tipo':'cod_tipo'
                       
})
df1=df1.copy()

# %%
df1.columns
# Out:
# Index(['data', 'hora', 'ocorrência', 'endereço', 'bairro', 'município',
#        'cod_tipo', 'descrição', 'cód. sub tipo', 'desc. sub tipo',
#        'sit. encontrada', 'descrição finalização', 'obs. finalização'],
#       dtype='object')

# %%
#Salva o arquivo em csv na pasta onde está solvo o notebook
df1.to_csv('df2.csv', index=False)

# %%
import pandas as pd
df2=pd.read_csv('df2.csv')
df2.sample().T
# Out:
#                                                                    13981
# data                                                          11/07/2021
# hora                                                            00:38:47
# ocorrência                                                      M2560873
# endereço               RUA A CJ BRG EDUARDO GOMES, 2 :NUMERAL INFORMA...
# bairro                                             .CJ BRG EDUARDO GOMES
# município                                                 .SAO CRISTOVAO
# cod_tipo                                                          E08420
# descrição                  PERTURBACAO DO TRABALHO OU DO SOSSEGO ALHEIOS
# cód. sub tipo                                                   E08420.1
# desc. sub tipo                                             EM RESIDENCIA
# sit. encontrada                                                      NaN
# descrição finalização                                    NADA CONSTATADO
# ...

# %%
# looking for the address
df2[df2['endereço'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('lazaro', case=False)]
# Out:
#              data      hora ocorrência  \
# 287    12/01/2020  19:03:01   M2286165
# 5562   09/08/2020  02:51:46   M2403480
# 6102   30/08/2020  03:18:07   M2413240
# 6291   06/09/2020  21:17:15   M2416759
# 6311   07/09/2020  00:23:25   M2416976
# 7961   15/11/2020  16:48:15   M2447477
# 9082   27/12/2020  18:19:25   M2466860
# 9087   27/12/2020  19:31:21   M2466903
# 9177   01/01/2021  00:36:07   M2468455
# 9972   01/02/2021  23:03:29   M2482195
# 10981  20/03/2021  17:15:40   M2504385
#
#                                      endereço           bairro  \
# 287                  RUA SAO LAZARO, 72 : EST  .LTM TIJUQUINHA
# 5562                RUA SAO LAZARO, 107 : EST  .LTM TIJUQUINHA
# 6102   RUA SAO LAZARO, 8 :NUMERAL INFORMADO 0  .LTM TIJUQUINHA
# 6291                   RUA S LAZARO, 61 : EST  .LTM TIJUQUINHA
# 6311                   RUA S LAZARO, 83 : EST  .LTM TIJUQUINHA
# 7961                RUA SAO LAZARO, 116 : EST  .LTM TIJUQUINHA
# ...

# %%
df2[df2['endereço'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('sao jorge', case=False)]
# Out:
#              data      hora ocorrência  \
# 11     01/01/2020  01:52:21   M2280620
# 22     01/01/2020  04:05:08   M2280837
# 576    28/01/2020  17:59:29   M2292485
# 1152   23/02/2020  21:02:23   M2304194
# 1372   01/03/2020  22:27:54   M2308146
# 1405   07/03/2020  00:56:03   M2309638
# 1495   09/03/2020  13:59:15   M2311345
# 2612   17/04/2020  19:03:08   M2337963
# 2661   19/04/2020  01:59:59   M2339133
# 2667   19/04/2020  03:09:02   M2339178
# 2671   19/04/2020  06:15:46   M2339224
# 2679   19/04/2020  15:09:37   M2339384
# 3097   03/05/2020  03:26:10   M2347728
# 3123   03/05/2020  18:18:10   M2348315
# 3734   26/05/2020  00:54:16   M2363581
# 3801   30/05/2020  21:50:22   M2365889
# 3861   31/05/2020  16:43:13   M2366614
# 3895   01/06/2020  01:59:35   M2367045
# 4084   10/06/2020  23:45:39   M2371882
# 4798   04/07/2020  22:53:00   M2386674
# 4815   05/07/2020  02:17:17   M2386982
# 4839   05/07/2020  17:36:33   M2387386
# 5306   26/07/2020  22:35:57   M2398129
# ...

# %%
df2[df2['endereço'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('carcara', case=False)]
# Out:
# Empty DataFrame
# Columns: [data, hora, ocorrência, endereço, bairro, município, cod_tipo, descrição, cód. sub tipo, desc. sub tipo, sit. encontrada, descrição finalização, obs. finalização]
# Index: []

# %%
df2[df2['endereço'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('karkara', case=False)]
# Out:
# Empty DataFrame
# Columns: [data, hora, ocorrência, endereço, bairro, município, cod_tipo, descrição, cód. sub tipo, desc. sub tipo, sit. encontrada, descrição finalização, obs. finalização]
# Index: []

# %%
df2[df2['endereço'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('chacara', case=False)]
# Out:
#              data      hora ocorrência                       endereço  \
# 9902   31/01/2021  00:43:29   M2481131  EST CHACARA DA MOCA, 40 : EST
# 9908   31/01/2021  15:11:13   M2481388  EST CHACARA DA MOCA, 41 : EST
# 13090  12/06/2021  20:35:46   M2546066  EST CHACARA DA MOCA, 46 : EST
#
#            bairro       município cod_tipo  \
# 9902   .A DEFINIR  .SAO CRISTOVAO   E08420
# 9908   .A DEFINIR  .SAO CRISTOVAO   E08420
# 13090  .A DEFINIR  .SAO CRISTOVAO   E08420
#
#                                            descrição cód. sub tipo  \
# 9902   PERTURBACAO DO TRABALHO OU DO SOSSEGO ALHEIOS      E08420.1
# 9908   PERTURBACAO DO TRABALHO OU DO SOSSEGO ALHEIOS      E08420.1
# 13090  PERTURBACAO DO TRABALHO OU DO SOSSEGO ALHEIOS      E08420.1
#
#       desc. sub tipo  sit. encontrada  \
# 9902   EM RESIDENCIA              NaN
# 9908   EM RESIDENCIA              NaN
# 13090  EM RESIDENCIA              NaN
#
#                                    descrição finalização obs. finalização
# ...

# %% [markdown]
# checking by district

# %%
df3=pd.read_excel("C:/Users/55799/Desktop/Repos/1cipm/df3.xls")

# %%
df3.isnull().sum()
# Out:
# Data de Criação              0
# Hora de Criação              0
# Ocorrência                   0
# Endereço                     0
# Bairro                       0
# Município                    0
# Cód. Tipo                    0
# Descrição                    0
# Cód. Sub Tipo               48
# Desc. Sub Tipo              48
# Sit. Encontrada          14544
# Batalhão                     0
# COMPANHIA                    0
# Viatura                   4763
# Cód. Final.                 21
# Descrição Finalização       21
# Obs. Finalização          9634
# Solicitante                 11
# Telefone                    66
# XCORD                        0
# YCORD                        0
# Aberto                       0
# Despachado                   0
# Tempo Despacho               0
# Chegada Local                0
# Tempo Deslocamento           0
# Fechado                      0
# Placa                    14544
# dtype: int64

# %%
df3.sample().T
# Out:
#                                                                13236
# Data de Criação                                           25/01/2021
# Hora de Criação                                             16:09:46
# Ocorrência                                                  M2479474
# Endereço                           RUA B LTM MAJ MARCOLINO, 65 : EST
# Bairro                                                           .NI
# Município                                         .ITAPORANGA DAJUDA
# Cód. Tipo                                                     E08420
# Descrição              PERTURBACAO DO TRABALHO OU DO SOSSEGO ALHEIOS
# Cód. Sub Tipo                                               E08420.1
# Desc. Sub Tipo                                         EM RESIDENCIA
# Sit. Encontrada                                                  NaN
# Batalhão                                                       1CIPM
# COMPANHIA                                                      1CIPM
# ...

# %%
df3[df3['Bairro'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('carcara', case=False)]
# Out:
# Empty DataFrame
# Columns: [Data de Criação, Hora de Criação, Ocorrência, Endereço, Bairro, Município, Cód. Tipo, Descrição, Cód. Sub Tipo, Desc. Sub Tipo, Sit. Encontrada, Batalhão, COMPANHIA, Viatura, Cód. Final., Descrição Finalização, Obs. Finalização, Solicitante, Telefone, XCORD, YCORD, Aberto, Despachado, Tempo Despacho, Chegada Local, Tempo Deslocamento, Fechado, Placa]
# Index: []
#
# [0 rows x 28 columns]

# %%
df3[df3['Bairro'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('sao jorge', case=False)]
# Out:
# Empty DataFrame
# Columns: [Data de Criação, Hora de Criação, Ocorrência, Endereço, Bairro, Município, Cód. Tipo, Descrição, Cód. Sub Tipo, Desc. Sub Tipo, Sit. Encontrada, Batalhão, COMPANHIA, Viatura, Cód. Final., Descrição Finalização, Obs. Finalização, Solicitante, Telefone, XCORD, YCORD, Aberto, Despachado, Tempo Despacho, Chegada Local, Tempo Deslocamento, Fechado, Placa]
# Index: []
#
# [0 rows x 28 columns]

# %%
df3[df3['Bairro'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('aningas', case=False)]
# Out:
# Empty DataFrame
# Columns: [Data de Criação, Hora de Criação, Ocorrência, Endereço, Bairro, Município, Cód. Tipo, Descrição, Cód. Sub Tipo, Desc. Sub Tipo, Sit. Encontrada, Batalhão, COMPANHIA, Viatura, Cód. Final., Descrição Finalização, Obs. Finalização, Solicitante, Telefone, XCORD, YCORD, Aberto, Despachado, Tempo Despacho, Chegada Local, Tempo Deslocamento, Fechado, Placa]
# Index: []
#
# [0 rows x 28 columns]

# %%
df3[df3['Bairro'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('chacara', case=False)]
# Out:
# Empty DataFrame
# Columns: [Data de Criação, Hora de Criação, Ocorrência, Endereço, Bairro, Município, Cód. Tipo, Descrição, Cód. Sub Tipo, Desc. Sub Tipo, Sit. Encontrada, Batalhão, COMPANHIA, Viatura, Cód. Final., Descrição Finalização, Obs. Finalização, Solicitante, Telefone, XCORD, YCORD, Aberto, Despachado, Tempo Despacho, Chegada Local, Tempo Deslocamento, Fechado, Placa]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ## Parque São Lázaro

# %%
df2[df2['endereço'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('lazaro', case=False)]
# Out:
#              data      hora ocorrência  \
# 287    12/01/2020  19:03:01   M2286165
# 5562   09/08/2020  02:51:46   M2403480
# 6102   30/08/2020  03:18:07   M2413240
# 6291   06/09/2020  21:17:15   M2416759
# 6311   07/09/2020  00:23:25   M2416976
# 7961   15/11/2020  16:48:15   M2447477
# 9082   27/12/2020  18:19:25   M2466860
# 9087   27/12/2020  19:31:21   M2466903
# 9177   01/01/2021  00:36:07   M2468455
# 9972   01/02/2021  23:03:29   M2482195
# 10981  20/03/2021  17:15:40   M2504385
#
#                                      endereço           bairro  \
# 287                  RUA SAO LAZARO, 72 : EST  .LTM TIJUQUINHA
# 5562                RUA SAO LAZARO, 107 : EST  .LTM TIJUQUINHA
# 6102   RUA SAO LAZARO, 8 :NUMERAL INFORMADO 0  .LTM TIJUQUINHA
# 6291                   RUA S LAZARO, 61 : EST  .LTM TIJUQUINHA
# 6311                   RUA S LAZARO, 83 : EST  .LTM TIJUQUINHA
# 7961                RUA SAO LAZARO, 116 : EST  .LTM TIJUQUINHA
# ...

# %%
df3[df3['Bairro'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('lazaro', case=False)]
# Out:
# Empty DataFrame
# Columns: [Data de Criação, Hora de Criação, Ocorrência, Endereço, Bairro, Município, Cód. Tipo, Descrição, Cód. Sub Tipo, Desc. Sub Tipo, Sit. Encontrada, Batalhão, COMPANHIA, Viatura, Cód. Final., Descrição Finalização, Obs. Finalização, Solicitante, Telefone, XCORD, YCORD, Aberto, Despachado, Tempo Despacho, Chegada Local, Tempo Deslocamento, Fechado, Placa]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ## Clube Beto Som (LAF)

# %%
df2[df2['endereço'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('beto', case=False)]
# Out:
# Empty DataFrame
# Columns: [data, hora, ocorrência, endereço, bairro, município, cod_tipo, descrição, cód. sub tipo, desc. sub tipo, sit. encontrada, descrição finalização, obs. finalização]
# Index: []

# %%
df3[df3['Bairro'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('LAF', case=False)]
# Out:
#      Data de Criação Hora de Criação Ocorrência  \
# 6355      01/01/2020        09:30:36   M2281187
# 6356      01/01/2020        10:45:57   M2281237
# 6357      01/01/2020        17:44:09   M2281587
# 6358      01/01/2020        18:10:02   M2281612
# 6359      04/01/2020        23:31:07   M2282957
# ...              ...             ...        ...
# 6614      02/08/2021        00:39:34   M2570324
# 6615      02/08/2021        01:41:31   M2570354
# 6616      06/08/2021        18:19:06   M2571464
# 6617      06/08/2021        20:08:11   M2571498
# 6618      07/08/2021        21:55:57   M2572149
#
#                                                Endereço                Bairro  \
# 6355  RUA I CJ LAFAYETE COUTINHO, 2 :NUMERAL INFORMA...  .CJ HABITACIONAL LAF
# 6356               RUA I CJ LAFAYETE COUTINHO, 21 : EST  .CJ HABITACIONAL LAF
# 6357                RUA M CJ LAFAYETE COUTINHO, 0 : EST  .CJ HABITACIONAL LAF
# ...

# %% [markdown]
# ## Exemplo de localização de endereço

# %%
df2.sample().T
# Out:
#                                                                 1411
# data                                                      07/03/2020
# hora                                                        16:07:44
# ocorrência                                                  M2309835
# endereço                        RUA C CJ LAFAYETE COUTINHO, 14 : EST
# bairro                                          .CJ HABITACIONAL LAF
# município                                             .SAO CRISTOVAO
# cod_tipo                                                      E08420
# descrição              PERTURBACAO DO TRABALHO OU DO SOSSEGO ALHEIOS
# cód. sub tipo                                               E08420.5
# desc. sub tipo                                        EM VIA PUBLICA
# sit. encontrada                                                  NaN
# descrição finalização                                NADA CONSTATADO
# obs. finalização                                                 NaN

# %%
# busca por endereço

df2[df2['ocorrência'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('M2282819', case=False)]
# Out:
#            data      hora ocorrência                      endereço  \
# 128  04/01/2020  21:25:38   M2282819  RUA NESTOR FRANCISCO NETO,
#
#          bairro       município cod_tipo  \
# 128  .A DEFINIR  .SAO CRISTOVAO   E08420
#
#                                          descrição cód. sub tipo  \
# 128  PERTURBACAO DO TRABALHO OU DO SOSSEGO ALHEIOS      E08420.3
#
#                    desc. sub tipo  sit. encontrada  \
# 128  EM ESTABELECIMENTO COMERCIAL              NaN
#
#                                  descrição finalização obs. finalização
# 128  FALTA DE VIATURA DISPONIVEL NA AREA E ESPECIAL...   tempo excedido

# %%
# Busca por Bairro

# %%
df3[df3['Bairro'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.contains('LAF', case=False)]
# Out:
#      Data de Criação Hora de Criação Ocorrência  \
# 6355      01/01/2020        09:30:36   M2281187
# 6356      01/01/2020        10:45:57   M2281237
# 6357      01/01/2020        17:44:09   M2281587
# 6358      01/01/2020        18:10:02   M2281612
# 6359      04/01/2020        23:31:07   M2282957
# ...              ...             ...        ...
# 6614      02/08/2021        00:39:34   M2570324
# 6615      02/08/2021        01:41:31   M2570354
# 6616      06/08/2021        18:19:06   M2571464
# 6617      06/08/2021        20:08:11   M2571498
# 6618      07/08/2021        21:55:57   M2572149
#
#                                                Endereço                Bairro  \
# 6355  RUA I CJ LAFAYETE COUTINHO, 2 :NUMERAL INFORMA...  .CJ HABITACIONAL LAF
# 6356               RUA I CJ LAFAYETE COUTINHO, 21 : EST  .CJ HABITACIONAL LAF
# 6357                RUA M CJ LAFAYETE COUTINHO, 0 : EST  .CJ HABITACIONAL LAF
# ...
